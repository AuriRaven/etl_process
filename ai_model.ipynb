# %% [markdown]
# # ETL PARA DATOS DE <font color='teal'>MODELO IA</font>
#
# -----------------------------------------
#
# En el siguiente trabajo, se hará un proceso ETL sobre datos referentes a un modelo de IA que trabaja reconociendo texto, imagen y también transcribiendo audio. Queremos encontrar aquellos datos referentes a detectar las siguientes marcas: Bimbo, Caliente, BARDAHL, Nike, Amazon y Tecate.

# %%
# Importamos las librerias necesarias
import json
import pandas as pd

# %%
# Usamos google drive para leer sus archivos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta_resultados = '/content/drive/My Drive/etl_datasets/resultados/results.json'

# %%
# Leemos el archivo json de la carpeta
with open(ruta_resultados, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Imprime las claves principales
print("Claves principales:", list(data.keys()))

# Dado que la clave principal es 'annotation_results'
# Accedemos a ella para ver su contenido
primer_nivel = data['annotation_results']

# Si es una lista, recórrela
for i, elemento in enumerate(primer_nivel):
    print(f"\nElemento {i}: claves -> {list(elemento.keys())}")
    # Si quieres ver el contenido de una clave específica:
    # print(elemento['nombre_de_la_clave'])

    # Si solo quieres ver un ejemplo y no todo el archivo, puedes hacer un break
    if i == 3:  # Solo muestra los primeros 4 elementos (si los hay)
        break
# Out:
# Claves principales: ['annotation_results']
#
# Elemento 0: claves -> ['input_uri', 'segment', 'segment_label_annotations', 'shot_label_annotations', 'text_annotations', 'logo_recognition_annotations']
#
# Elemento 1: claves -> ['input_uri', 'segment', 'speech_transcriptions']

# %% [markdown]
# Observemos que esto ya nos da una pista de como se estructuran los datos en este archivo. Podemos ya incluso ver donde ubicar respuestas del modelo IA respecto a texto, audio e imagen.

# %%
with open(ruta_resultados, 'r', encoding='utf-8') as file:
    data = json.load(file)

primer_nivel = data['annotation_results']

for i, elemento in enumerate(primer_nivel):
    print(f"\nElemento {i}: claves -> {list(elemento.keys())}")
    for clave in elemento:
        print(f"  - {clave}: tipo {type(elemento[clave])}")
        # Si quieres ver un ejemplo del contenido:
        if isinstance(elemento[clave], list) and len(elemento[clave]) > 0:
            print(f"    Ejemplo contenido: {elemento[clave][0]}")
        elif isinstance(elemento[clave], dict):
            print(f"    Ejemplo contenido: {list(elemento[clave].items())[:1]}")
        else:
            print(f"    Valor: {elemento[clave]}")
    if i == 2:  # Solo muestra los primeros 3 elementos
        break
# Out:
# Elemento 0: claves -> ['input_uri', 'segment', 'segment_label_annotations', 'shot_label_annotations', 'text_annotations', 'logo_recognition_annotations']
#   - input_uri: tipo <class 'str'>
#     Valor: /vboxio-off/partidos/2025/TUDN/apertura/jornada_02/AMERICA_TIJUANA/16-07-2025_TU_APE_J02_AMETIJ.mkv
#   - segment: tipo <class 'dict'>
#     Ejemplo contenido: [('start_time_offset', {})]
#   - segment_label_annotations: tipo <class 'list'>
#     Ejemplo contenido: {'entity': {'entity_id': '/m/02vx4', 'description': 'soccer', 'language_code': 'en-US'}, 'category_entities': [{'entity_id': '/m/06ntj', 'description': 'sports', 'language_code': 'en-US'}], 'segments': [{'segment': {'start_time_offset': {}, 'end_time_offset': {'seconds': 8133, 'nanos': 933333000}}, 'confidence': 0.70713681}]}
#   - shot_label_annotations: tipo <class 'list'>
#     Ejemplo contenido: {'entity': {'entity_id': '/m/02qdwbp', 'description': 'net', 'language_code': 'en-US'}, 'segments': [{'segment': {'start_time_offset': {'seconds': 68, 'nanos': 533333000}, 'end_time_offset': {'seconds': 296, 'nanos': 733333000}}, 'confidence': 0.50360262}, {'segment': {'start_time_offset': {'seconds': 4323, 'nanos': 433333000}, 'end_time_offset': {'seconds': 4324, 'nanos': 633333000}}, 'confidence': 0.37371165}, {'segment': {'start_time_offset': {'seconds': 4369, 'nanos': 33333000}, 'end_time_offset': {'seconds': 4370, 'nanos': 66666000}}, 'confidence': 0.71415424}]}
#   - text_annotations: tipo <class 'list'>
#     Ejemplo contenido: {'text': 'LASTANEDA', 'segments': [{'segment': {'start_time_offset': {'seconds': 5323}, 'end_time_offset': {'seconds': 5323, 'nanos': 300000000}}, 'confidence': 0.88254505, 'frames': [{'rotated_bounding_box': {'vertices': [{'x': 0.53359377, 'y': 0.72777778}, {'x': 0.60764056, 'y': 0.71880233}, {'x': 0.60896921, 'y': 0.75344414}, {'x': 0.53492236, 'y': 0.76241958}]}, 'time_offset': {'seconds': 5323}}, {'rotated_bounding_box': {'vertices': [{'x': 0.53828126, 'y': 0.71805555}, {'x': 0.62085891, 'y': 0.70697594}, {'x': 0.62262279, 'y': 0.74852443}, {'x': 0.54004508, 'y': 0.75960404}]}, 'time_offset': {'seconds': 5323, 'nanos': 100000000}}, {'rotated_bounding_box': {'vertices': [{'x': 0.546875, 'y': 0.70833331}, {'x': 0.62721515, 'y': 0.70024884}, {'x': 0.62858385, 'y': 0.74323559}, {'x': 0.5482437, 'y': 0.75132006}]}, 'time_offset': {'seconds': 5323, 'nanos': 200000000}}, {'rotated_bounding_box': {'vertices': [{'x': 0.55937499, 'y': 0.7027778}, {'x': 0.63948804, 'y': 0.6893416}, {'x': 0.64176273, 'y': 0.73220688}, {'x': 0.56164968, 'y': 0.74564302}]}, 'time_offset': {'seconds': 5323, 'nanos': 300000000}}]}, {'segment': {'start_time_offset': {'seconds': 5341, 'nanos': 800000000}, 'end_time_offset': {'seconds': 5341, 'nanos': 800000000}}, 'confidence': 0.81118816, 'frames': [{'rotated_bounding_box': {'vertices': [{'x': 0.32343751, 'y': 0.8125}, {'x': 0.41479623, 'y': 0.80726081}, {'x': 0.41572821, 'y': 0.85862303}, {'x': 0.32436946, 'y': 0.86386216}]}, 'time_offset': {'seconds': 5341, 'nanos': 800000000}}]}, {'segment': {'start_time_offset': {'seconds': 7866, 'nanos': 700000000}, 'end_time_offset': {'seconds': 7866, 'nanos': 700000000}}, 'confidence': 0.91326231, 'frames': [{'rotated_bounding_box': {'vertices': [{'x': 0.63125002, 'y': 0.65833336}, {'x': 0.68203127, 'y': 0.65833336}, {'x': 0.68203127, 'y': 0.68333334}, {'x': 0.63125002, 'y': 0.68333334}]}, 'time_offset': {'seconds': 7866, 'nanos': 700000000}}]}]}
#   - logo_recognition_annotations: tipo <class 'list'>
#     Ejemplo contenido: {'entity': {'entity_id': '/m/065_m99', 'description': 'Gafisa', 'language_code': 'en-US'}, 'tracks': [{'segment': {'start_time_offset': {'seconds': 2521, 'nanos': 700000000}, 'end_time_offset': {'seconds': 2522, 'nanos': 200000000}}, 'timestamped_objects': [{'normalized_bounding_box': {'left': 0.17017114, 'top': 0.72630626, 'right': 0.25568089, 'bottom': 0.84519523}, 'time_offset': {'seconds': 2521, 'nanos': 700000000}}, {'normalized_bounding_box': {'left': 0.27620301, 'top': 0.72526777, 'right': 0.35913646, 'bottom': 0.83483517}, 'time_offset': {'seconds': 2521, 'nanos': 800000000}}, {'normalized_bounding_box': {'left': 0.35707051, 'top': 0.69819462, 'right': 0.44098359, 'bottom': 0.80958068}, 'time_offset': {'seconds': 2521, 'nanos': 900000000}}, {'normalized_bounding_box': {'left': 0.42261553, 'top': 0.67085069, 'right': 0.50357723, 'bottom': 0.77780616}, 'time_offset': {'seconds': 2522}}, {'normalized_bounding_box': {'left': 0.46620616, 'top': 0.65009052, 'right': 0.54301625, 'bottom': 0.74901497}, 'time_offset': {'seconds': 2522, 'nanos': 100000000}}, {'normalized_bounding_box': {'left': 0.48029542, 'top': 0.63152909, 'right': 0.56292588, 'bottom': 0.73195243}, 'time_offset': {'seconds': 2522, 'nanos': 200000000}}], 'confidence': 0.87136674}], 'segments': [{'start_time_offset': {'seconds': 2521, 'nanos': 700000000}, 'end_time_offset': {'seconds': 2522, 'nanos': 200000000}}]}
#
# Elemento 1: claves -> ['input_uri', 'segment', 'speech_transcriptions']
#   - input_uri: tipo <class 'str'>
#     Valor: /vboxio-off/partidos/2025/TUDN/apertura/jornada_02/AMERICA_TIJUANA/16-07-2025_TU_APE_J02_AMETIJ.mkv
#   - segment: tipo <class 'dict'>
#     Ejemplo contenido: [('start_time_offset', {})]
#   - speech_transcriptions: tipo <class 'list'>
#     Ejemplo contenido: {'alternatives': [{'transcript': 'Bueno, que también se metió en polémica ruso después las declaraciones, qué dijo hablando de zonas y demás y no me hablen de zona. Yo no soy Juan Carlos Osorio dijo El loco, Abreu vamos a hablar mucho más claro y bueno, cada cada entrenador maneja, su lenguaje, el fútbol es universal y también transmitírselo a la gente de la forma más simple posible.', 'confidence': 0.84355307, 'words': [{'start_time': {}, 'end_time': {'seconds': 36, 'nanos': 300000000}, 'word': 'Bueno,'}, {'start_time': {'seconds': 36, 'nanos': 300000000}, 'end_time': {'seconds': 36, 'nanos': 500000000}, 'word': 'que'}, {'start_time': {'seconds': 36, 'nanos': 500000000}, 'end_time': {'seconds': 37, 'nanos': 300000000}, 'word': 'también'}, {'start_time': {'seconds': 37, 'nanos': 300000000}, 'end_time': {'seconds': 37, 'nanos': 700000000}, 'word': 'se'}, {'start_time': {'seconds': 37, 'nanos': 700000000}, 'end_time': {'seconds': 37, 'nanos': 900000000}, 'word': 'metió'}, {'start_time': {'seconds': 37, 'nanos': 900000000}, 'end_time': {'seconds': 38}, 'word': 'en'}, {'start_time': {'seconds': 38}, 'end_time': {'seconds': 38, 'nanos': 500000000}, 'word': 'polémica'}, {'start_time': {'seconds': 38, 'nanos': 500000000}, 'end_time': {'seconds': 39, 'nanos': 100000000}, 'word': 'ruso'}, {'start_time': {'seconds': 39, 'nanos': 100000000}, 'end_time': {'seconds': 39, 'nanos': 700000000}, 'word': 'después'}, {'start_time': {'seconds': 39, 'nanos': 700000000}, 'end_time': {'seconds': 39, 'nanos': 800000000}, 'word': 'las'}, {'start_time': {'seconds': 39, 'nanos': 800000000}, 'end_time': {'seconds': 40, 'nanos': 400000000}, 'word': 'declaraciones,'}, {'start_time': {'seconds': 40, 'nanos': 400000000}, 'end_time': {'seconds': 40, 'nanos': 600000000}, 'word': 'qué'}, {'start_time': {'seconds': 40, 'nanos': 600000000}, 'end_time': {'seconds': 40, 'nanos': 700000000}, 'word': 'dijo'}, {'start_time': {'seconds': 40, 'nanos': 700000000}, 'end_time': {'seconds': 41, 'nanos': 200000000}, 'word': 'hablando'}, {'start_time': {'seconds': 41, 'nanos': 200000000}, 'end_time': {'seconds': 41, 'nanos': 300000000}, 'word': 'de'}, {'start_time': {'seconds': 41, 'nanos': 300000000}, 'end_time': {'seconds': 41, 'nanos': 900000000}, 'word': 'zonas'}, {'start_time': {'seconds': 41, 'nanos': 900000000}, 'end_time': {'seconds': 42}, 'word': 'y'}, {'start_time': {'seconds': 42}, 'end_time': {'seconds': 42, 'nanos': 400000000}, 'word': 'demás'}, {'start_time': {'seconds': 42, 'nanos': 400000000}, 'end_time': {'seconds': 42, 'nanos': 500000000}, 'word': 'y'}, {'start_time': {'seconds': 42, 'nanos': 500000000}, 'end_time': {'seconds': 42, 'nanos': 600000000}, 'word': 'no'}, {'start_time': {'seconds': 42, 'nanos': 600000000}, 'end_time': {'seconds': 44, 'nanos': 100000000}, 'word': 'me'}, {'start_time': {'seconds': 44, 'nanos': 100000000}, 'end_time': {'seconds': 44, 'nanos': 600000000}, 'word': 'hablen'}, {'start_time': {'seconds': 44, 'nanos': 600000000}, 'end_time': {'seconds': 44, 'nanos': 700000000}, 'word': 'de'}, {'start_time': {'seconds': 44, 'nanos': 700000000}, 'end_time': {'seconds': 45}, 'word': 'zona.'}, {'start_time': {'seconds': 45}, 'end_time': {'seconds': 45, 'nanos': 200000000}, 'word': 'Yo'}, {'start_time': {'seconds': 45, 'nanos': 200000000}, 'end_time': {'seconds': 45, 'nanos': 300000000}, 'word': 'no'}, {'start_time': {'seconds': 45, 'nanos': 300000000}, 'end_time': {'seconds': 45, 'nanos': 500000000}, 'word': 'soy'}, {'start_time': {'seconds': 45, 'nanos': 500000000}, 'end_time': {'seconds': 45, 'nanos': 700000000}, 'word': 'Juan'}, {'start_time': {'seconds': 45, 'nanos': 700000000}, 'end_time': {'seconds': 46}, 'word': 'Carlos'}, {'start_time': {'seconds': 46}, 'end_time': {'seconds': 46, 'nanos': 200000000}, 'word': 'Osorio'}, {'start_time': {'seconds': 46, 'nanos': 200000000}, 'end_time': {'seconds': 46, 'nanos': 600000000}, 'word': 'dijo'}, {'start_time': {'seconds': 46, 'nanos': 600000000}, 'end_time': {'seconds': 4 ...

# %% [markdown]
# Procedemos a restringir la información según las marcas que nos interesa observar.

# %%
# Definimos las marcas de interes
marcas_interes = ['bimbo', 'caliente', 'bardahl', 'nike', 'amazon', 'tecate']

# Forzamos a la lectura de archivos a encontrar coincidencias de
# palabras de marcas de interes a traves de las llaves
with open(ruta_resultados, 'r', encoding='utf-8') as file:
    data = json.load(file)

resultados = []
for elemento in data['annotation_results']:
    input_uri = elemento.get('input_uri', '')
    if 'text_annotations' in elemento:
        for texto in elemento['text_annotations']:
            texto_detectado = texto.get('text', '')
            # Normaliza el texto: minúsculas y separa por palabras
            palabras = [palabra.strip().lower() for palabra in texto_detectado.split()]
            # Busca si alguna marca está en las palabras detectadas
            marcas_encontradas = [marca for marca in marcas_interes if marca in palabras]
            for marca in marcas_encontradas:
                resultados.append({
                    'input_uri': input_uri,
                    'marca_detectada': marca,
                    'texto_original': texto_detectado
                })

# Crear DataFrame
df = pd.DataFrame(resultados)
print(df.head())
# Out:
#                                            input_uri marca_detectada  \
# 0  /vboxio-off/partidos/2025/TUDN/apertura/jornad...          amazon
# 1  /vboxio-off/partidos/2025/TUDN/apertura/jornad...           bimbo
# 2  /vboxio-off/partidos/2025/TUDN/apertura/jornad...        caliente
# 3  /vboxio-off/partidos/2025/TUDN/apertura/jornad...         bardahl
# 4  /vboxio-off/partidos/2025/TUDN/apertura/jornad...         bardahl
#
#                                       texto_original
# 0  15 al 21 de julio Grandes ofertas amazon prime...
# 1                                         cond BIMBO
# 2               BARDAHL C caliente.mx 6 caliente TIX
# 3               BARDAHL C caliente.mx 6 caliente TIX
# 4                       BARDAHL e caliente.mx reSTOI

# %% [markdown]
# Ahora, necesitamos crear funciones que nos ayuden a medir como fueron las detecciones del modelo de IA segun sea el formato (audio, texto, imagen). Requerimos de usar otras llaves complemetarias en el archivo JSON que nos permitiran calcular las variables de Tiempo de detección, Duración y Área. Todo esto se agregrará a nuestra tabla estructurada final.

# %%
# Funciones para ordenar valores en tabla estructurada
def calcular_area(vertices):
    # Solo toma vértices que tengan 'x' y 'y'
    xs = [v['x'] for v in vertices if 'x' in v and 'y' in v]
    ys = [v['y'] for v in vertices if 'x' in v and 'y' in v]
    if not xs or not ys:
        return None
    ancho = max(xs) - min(xs)
    alto = max(ys) - min(ys)
    return round(ancho * alto * 100, 2)  # porcentaje

def calcular_area_logo(bbox):
    # Verifica que existan todas las claves necesarias
    if not all(k in bbox for k in ['left', 'top', 'right', 'bottom']):
        return None
    ancho = bbox['right'] - bbox['left']
    alto = bbox['bottom'] - bbox['top']
    return round(ancho * alto * 100, 2)  # porcentaje

def offset_a_segundos(offset):
    if not offset:
        return 0
    return offset.get('seconds', 0) + offset.get('nanos', 0)/1e9

with open(ruta_resultados, 'r', encoding='utf-8') as file:
    data = json.load(file)

resultados = []

for elemento in data['annotation_results']:
    input_uri = elemento.get('input_uri', '')

    # --- TEXTO (OCR) ---
    for texto in elemento.get('text_annotations', []):
        texto_detectado = texto.get('text', '')
        palabras = [palabra.strip().lower() for palabra in texto_detectado.split()]
        marcas_encontradas = [marca for marca in marcas_interes if marca in palabras]
        for marca in marcas_encontradas:
            for segmento in texto.get('segments', []):
                seg = segmento.get('segment', {})
                inicio = offset_a_segundos(seg.get('start_time_offset', {}))
                fin = offset_a_segundos(seg.get('end_time_offset', {}))
                duracion = max(0, fin - inicio)
                area = None
                # Buscar área en frames (si existe)
                frames = segmento.get('frames', [])
                if frames:
                    # Tomar el área del primer frame como ejemplo
                    vertices = frames[0].get('rotated_bounding_box', {}).get('vertices', [])
                    if vertices:
                        area = calcular_area(vertices)
                resultados.append({
                    'Marca': marca,
                    'Tiempo de detección': inicio,
                    'Duración': duracion,
                    'Área': area,
                    'Modo de detección': 'texto',
                    'input_uri': input_uri
                })

    # --- LOGOS ---
    for logo in elemento.get('logo_recognition_annotations', []):
        marca_logo = logo.get('entity', {}).get('description', '').strip().lower()
        if marca_logo in marcas_interes:
            for track in logo.get('tracks', []):
                seg = track.get('segment', {})
                inicio = offset_a_segundos(seg.get('start_time_offset', {}))
                fin = offset_a_segundos(seg.get('end_time_offset', {}))
                duracion = max(0, fin - inicio)
                area = None
                # Buscar área en timestamped_objects
                objs = track.get('timestamped_objects', [])
                if objs:
                    bbox = objs[0].get('normalized_bounding_box', {})
                    if bbox:
                        area = calcular_area_logo(bbox)
                resultados.append({
                    'Marca': marca_logo,
                    'Tiempo de detección': inicio,
                    'Duración': duracion,
                    'Área': area,
                    'Modo de detección': 'logo',
                    'input_uri': input_uri
                })

    # --- AUDIO ---
    for transcripcion in elemento.get('speech_transcriptions', []):
        for alternativa in transcripcion.get('alternatives', []):
            transcript = alternativa.get('transcript', '').lower()
            for marca in marcas_interes:
                if marca in transcript:
                    # Buscar la palabra y su tiempo
                    for palabra in alternativa.get('words', []):
                        if marca in palabra.get('word', '').lower():
                            inicio = offset_a_segundos(palabra.get('start_time', {}))
                            fin = offset_a_segundos(palabra.get('end_time', {}))
                            duracion = max(0, fin - inicio)
                            resultados.append({
                                'Marca': marca,
                                'Tiempo de detección': inicio,
                                'Duración': duracion,
                                'Área': None,
                                'Modo de detección': 'audio',
                                'input_uri': input_uri
                            })

# Crear DataFrame final
df = pd.DataFrame(resultados)
print(df.head())
# Out:
#       Marca  Tiempo de detección  Duración  Área Modo de detección  \
# 0    amazon               2981.4       0.0  2.62             texto
# 1     bimbo               1678.2       0.4  0.80             texto
# 2  caliente               4780.8       0.0  3.33             texto
# 3   bardahl               4780.8       0.0  3.33             texto
# 4   bardahl               5687.6       0.0  3.72             texto
#
#                                            input_uri
# 0  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 1  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 2  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 3  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 4  /vboxio-off/partidos/2025/TUDN/apertura/jornad...

# %%
df.head()
# Out:
#       Marca  Tiempo de detección  Duración  Área Modo de detección  \
# 0    amazon               2981.4       0.0  2.62             texto
# 1     bimbo               1678.2       0.4  0.80             texto
# 2  caliente               4780.8       0.0  3.33             texto
# 3   bardahl               4780.8       0.0  3.33             texto
# 4   bardahl               5687.6       0.0  3.72             texto
#
#                                            input_uri
# 0  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 1  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 2  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 3  /vboxio-off/partidos/2025/TUDN/apertura/jornad...
# 4  /vboxio-off/partidos/2025/TUDN/apertura/jornad...

# %% [markdown]
# Procedemos a eliminar la columna que no necesitamos

# %%
df = df.drop(['input_uri'], axis=1)

# %%
df.head()
# Out:
#       Marca  Tiempo de detección  Duración  Área Modo de detección
# 0    amazon               2981.4       0.0  2.62             texto
# 1     bimbo               1678.2       0.4  0.80             texto
# 2  caliente               4780.8       0.0  3.33             texto
# 3   bardahl               4780.8       0.0  3.33             texto
# 4   bardahl               5687.6       0.0  3.72             texto

# %%
df.shape
# Out:
# (9211, 5)

# %% [markdown]
# Luego, revisamos valores nulos.

# %%
df.isnull().sum().sort_values(ascending=False) / df.shape[0]
# Out:
# Área                   0.000543
# Marca                  0.000000
# Tiempo de detección    0.000000
# Duración               0.000000
# Modo de detección      0.000000
# dtype: float64

# %% [markdown]
# Imputamos los valores nulos con la media

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df['Área'] = imputer.fit_transform(df[['Área']])

# %%
df.isnull().sum().sort_values(ascending=False) / df.shape[0]
# Out:
# Marca                  0.0
# Tiempo de detección    0.0
# Duración               0.0
# Área                   0.0
# Modo de detección      0.0
# dtype: float64

# %% [markdown]
# Finalmente, guardamos la nueva tabla estructurada con los datos ya transformados.

# %%
df.to_csv('tabla_ia_estructurada.csv')
